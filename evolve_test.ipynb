# %% [markdown]
# # LWFA test

# %%
# %reload_ext autoreload
# %autoreload 2

# %%
from submissions.evolve.object_detector import ObjectDetector
from transformers import DetrImageProcessor, DetrForObjectDetection, DetrConfig

# %% [markdown]
# ## 1. Model creation and exam

# %%
# reduce the input channels to 2
lwfa_config = DetrConfig(num_channels=2)
model2 = DetrForObjectDetection
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[25], line 1
# ----> 1 model2 = DetrForObjectDetection.config(
#       2             "facebook/detr-resnet-50", revision="no_timm", num_channels=2
#       3         )
#
# AttributeError: type object 'DetrForObjectDetection' has no attribute 'config'

# %%
model
# Out:
# DetrForObjectDetection(
#   (model): DetrModel(
#     (backbone): DetrConvModel(
#       (conv_encoder): DetrConvEncoder(
#         (model): ResNetBackbone(
#           (embedder): ResNetEmbeddings(
#             (embedder): ResNetConvLayer(
#               (convolution): Conv2d(3, 64, kernel_size=(7, 7), stride=(2, 2), padding=(3, 3), bias=False)
#               (normalization): DetrFrozenBatchNorm2d()
#               (activation): ReLU()
#             )
#             (pooler): MaxPool2d(kernel_size=3, stride=2, padding=1, dilation=1, ceil_mode=False)
#           )
#           (encoder): ResNetEncoder(
#             (stages): ModuleList(
#               (0): ResNetStage(
#                 (layers): Sequential(
#                   (0): ResNetBottleNeckLayer(
#                     (shortcut): ResNetShortCut(
#                       (convolution): Conv2d(64, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#                       (normalization): DetrFrozenBatchNorm2d()
# ...

# %%
model3 = DetrForObjectDetection.from_pretrained(
    "facebook/detr-resnet-50", revision="no_timm", num_channels=3
)
model3
# Out:
# DetrForObjectDetection(
#   (model): DetrModel(
#     (backbone): DetrConvModel(
#       (conv_encoder): DetrConvEncoder(
#         (model): ResNetBackbone(
#           (embedder): ResNetEmbeddings(
#             (embedder): ResNetConvLayer(
#               (convolution): Conv2d(3, 64, kernel_size=(7, 7), stride=(2, 2), padding=(3, 3), bias=False)
#               (normalization): DetrFrozenBatchNorm2d()
#               (activation): ReLU()
#             )
#             (pooler): MaxPool2d(kernel_size=3, stride=2, padding=1, dilation=1, ceil_mode=False)
#           )
#           (encoder): ResNetEncoder(
#             (stages): ModuleList(
#               (0): ResNetStage(
#                 (layers): Sequential(
#                   (0): ResNetBottleNeckLayer(
#                     (shortcut): ResNetShortCut(
#                       (convolution): Conv2d(64, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#                       (normalization): DetrFrozenBatchNorm2d()
# ...

# %%
od = ObjectDetector()
# Out:
# preprocessor_config.json:   0%|          | 0.00/401 [00:00<?, ?B/s]
# config.json:   0%|          | 0.00/6.60k [00:00<?, ?B/s]
# pytorch_model.bin:   0%|          | 0.00/167M [00:00<?, ?B/s]
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[13], line 1
# ----> 1 od = ObjectDetector()
#
# File ~/Documents/Informatique/Git_reps/datacamp/datacamp-challenges/lwfa/submissions/evolve/object_detector.py:23, in ObjectDetector.__init__(self)
#      17 self.model = DetrForObjectDetection.from_pretrained(
#      18     "facebook/detr-resnet-50", revision="no_timm"
#      19 )
#      21 # Modify the first conv layer to accept 2 channels instead of 3
#      22 # original_conv = self.model.backbone.body.conv1
# ---> 23 self.model.backbone.body.conv1 = nn.Sequential(
#      24     nn.Conv2d(2, 64, kernel_size=7, stride=2, padding=3, bias=False),
#      25     nn.BatchNorm2d(64),
# ...

# %%
od.model
# Out:
# FasterRCNN(
#   (transform): GeneralizedRCNNTransform(
#       Normalize(mean=[0.485, 0.456], std=[0.229, 0.224])
#       Resize(min_size=(640,), max_size=800, mode='bilinear')
#   )
#   (backbone): BackboneWithFPN(
#     (body): IntermediateLayerGetter(
#       (conv1): Sequential(
#         (0): Conv2d(2, 64, kernel_size=(7, 7), stride=(2, 2), padding=(3, 3), bias=False)
#         (1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (2): ReLU(inplace=True)
#       )
#       (bn1): FrozenBatchNorm2d(64, eps=0.0)
#       (relu): ReLU(inplace=True)
#       (maxpool): MaxPool2d(kernel_size=3, stride=2, padding=1, dilation=1, ceil_mode=False)
#       (layer1): Sequential(
#         (0): Bottleneck(
#           (conv1): Conv2d(64, 64, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn1): FrozenBatchNorm2d(64, eps=0.0)
#           (conv2): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
# ...

# %% [markdown]
# ## 2. Training

# %%
import problem

X_train, y_train = problem.get_train_data()
print(f"{X_train.shape=} , {y_train.shape=}")

X_test, y_test = problem.get_test_data()
print(f"{X_test.shape=}, {y_test.shape=}")
# Out:
# X_train.shape=(1004,) , y_train.shape=(1004,)
# X_test.shape=(252,), y_test.shape=(252,)
